# %%
import pandas as pd
import yfinance as yf
df=yf.download("TMCV.NS", start="2025-01-01", end="2026-01-01")
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker         TMCV.NS     TMCV.NS     TMCV.NS     TMCV.NS    TMCV.NS
# Date
# 2025-11-12  325.772614  341.149029  316.428085  331.260651   31273277
# 2025-11-13  317.169708  322.361106  312.472729  313.066038   12079524
# 2025-11-14  314.054871  331.260641  302.880986  306.539698  165519798
# 2025-11-17  318.999054  321.866677  309.506206  318.207966   17163624
# 2025-11-18  321.520569  323.349925  306.539684  313.659327   13458307

# %%
# !pip install pandas matplotlib yfinance
# Out:
# Requirement already satisfied: pandas in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.3)
# Requirement already satisfied: matplotlib in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.0)
# Requirement already satisfied: yfinance in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=2.3.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: requests>=2.31 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: multitasking>=0.0.7 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (4.10.0)
# Requirement already satisfied: pytz>=2022.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (2026.2)
# Requirement already satisfied: peewee>=3.16.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (4.0.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (7.35.1)
# Requirement already satisfied: websockets>=13.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.5.20)
# Requirement already satisfied: rich in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)

# %%
# !pip install pandas matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.9 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.9 MB 1.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.9 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1
MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.5 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 1.2 MB/s  0:00:10
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 989.0 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.8/7.2 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.2 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.2 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.3/7.2 MB 1.0 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.2 MB 1.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 1.8/7.2 MB 1.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.1/7.2 MB 1.1 MB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.2 MB 1.1 MB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.2 MB 1.1 MB/s eta 0:00:05
#    -------------- ------------------------- 2.6/7.2 MB 1.0 MB/s eta 0:00:05
#    --------------- ------------------------ 2.9/7.2 MB 1.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 3.1/7.2 MB 1.1 MB/s eta 0:00:04
#    ------------------ --------------------- 3.4/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    --------------------- ------------------ 3.9/7.2 MB 1.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.2 MB 1.1 MB/s eta 0:00:03
#    ------------------------ --------------- 4.5/7.2 MB 1.1 MB/s eta 0:00:03
#    -------------------------- ------------- 4.7/7.2 MB 1.1 MB/s eta 0:00:03
#    --------------------------- ------------ 5.0/7.2 MB 1.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.2 MB 1.1 MB/s eta 0:00:02
#    ------------------------------ --------- 5.5/7.2 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 5.8/7.2 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 6.0/7.2 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 6.3/7.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 1.1 MB/s  0:00:06
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
#
#    ---------------------------------------- 0/9 [pyparsing]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    ---- ----------------------------------- 1/9 [pillow]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    ------------- -------------------------- 3/9 [kiwisolver]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ---------------------- ----------------- 5/9 [cycler]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    ------------------------------- -------- 7/9 [contourpy]
#    ------------------------------- -------- 7/9 [contourpy]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [matplotlib]
#    ---------------------------------------- 9/9 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 numpy-2.4.6 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
df=pd.read_csv("tata_motors.csv")
print(df.head())
df.head(5)
# Out:
#          Date  Open  High  Low  Close   Volume
# 0  2024-06-01   950   960  940    955  1200000
# 1  2024-06-02   955   970  950    965  1400000
# 2  2024-06-03   965   980  960    975  1500000
# 3  2024-06-04   975   990  970    985  1600000
# 4  2024-06-05   985  1000  980    995  1700000
#          Date  Open  High  Low  Close   Volume
# 0  2024-06-01   950   960  940    955  1200000
# 1  2024-06-02   955   970  950    965  1400000
# 2  2024-06-03   965   980  960    975  1500000
# 3  2024-06-04   975   990  970    985  1600000
# 4  2024-06-05   985  1000  980    995  1700000

# %%
import matplotlib.pyplot as plt
df['Date'] = pd.to_datetime(df['Date'])

# Plot Close price
plt.figure()
plt.plot(df['Date'], df['Close'])
plt.title("Tata Motors Price")
plt.xticks(rotation=45)
plt.show()

# %%
# Create Moving Averages
df['MA20'] = df['Close'].rolling(window=20).mean()
df['MA50'] = df['Close'].rolling(window=50).mean()

# Check data
print(df[['Date', 'Close', 'MA20', 'MA50']].tail())
# Out:
#         Date  Close  MA20  MA50
# 5 2024-06-06   1005   NaN   NaN
# 6 2024-06-07   1015   NaN   NaN
# 7 2024-06-08   1025   NaN   NaN
# 8 2024-06-09   1035   NaN   NaN
# 9 2024-06-10   1045   NaN   NaN

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['MA20'], label='MA20')
plt.plot(df['Date'], df['MA50'], label='MA50')

plt.legend()
plt.title("Tata Motors Moving Average Strategy")
plt.xticks(rotation=45)
plt.show()

# %%
# Create Signal column
df['Signal'] = 0

# When MA20 > MA50 → Buy (1), else Sell (0)
df['Signal'] = (df['MA20'] > df['MA50']).astype(int)

# Create Position (to detect crossover)
df['Position'] = df['Signal'].diff()

# Show where signals happen
print(df[['Date', 'Close', 'MA20', 'MA50', 'Signal', 'Position']].tail(20))
# Out:
#         Date  Close  MA20  MA50  Signal  Position
# 0 2024-06-01    955   NaN   NaN       0       NaN
# 1 2024-06-02    965   NaN   NaN       0       0.0
# 2 2024-06-03    975   NaN   NaN       0       0.0
# 3 2024-06-04    985   NaN   NaN       0       0.0
# 4 2024-06-05    995   NaN   NaN       0       0.0
# 5 2024-06-06   1005   NaN   NaN       0       0.0
# 6 2024-06-07   1015   NaN   NaN       0       0.0
# 7 2024-06-08   1025   NaN   NaN       0       0.0
# 8 2024-06-09   1035   NaN   NaN       0       0.0
# 9 2024-06-10   1045   NaN   NaN       0       0.0

# %%
plt.figure()

# Plot lines
plt.plot(df['Date'], df['Close'], label='Close', alpha=0.5)
plt.plot(df['Date'], df['MA20'], label='MA20')
plt.plot(df['Date'], df['MA50'], label='MA50')

# Buy signal (green)
plt.scatter(df[df['Position'] == 1]['Date'],
            df[df['Position'] == 1]['Close'],
            label='BUY', marker='^')

# Sell signal (red)
plt.scatter(df[df['Position'] == -1]['Date'],
            df[df['Position'] == -1]['Close'],
            label='SELL', marker='v')

plt.legend()
plt.title("Tata Motors Buy/Sell Signals")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 4
#       1 plt.figure()
#       2
#       3 # Plot lines
# ----> 4 plt.plot(df['Date'], df['Close'], label='Close', alpha=0.5)
#       5 plt.plot(df['Date'], df['MA20'], label='MA20')
#       6 plt.plot(df['Date'], df['MA50'], label='MA50')
#       7
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4377, in DataFrame.__getitem__(self, key)
#    4373         is_single_key = isinstance(key, tuple) or not is_list_like(key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
# -> 4377                 return self._getitem_multilevel(key)
#    4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4435, in DataFrame._getitem_multilevel(self, key)
#    4433     def _getitem_multilevel(self, key):
#    4434         # self.columns is a MultiIndex
# -> 4435         loc = self.columns.get_loc(key)
#    4436         if isinstance(loc, (slice, np.ndarray)):
#    4437             new_columns = self.columns[loc]
#    4438             result_columns = maybe_droplevels(new_columns, key)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\multi.py:3523, in MultiIndex.get_loc(self, key)
#    3520     return mask
#    3522 if not isinstance(key, tuple):
# -> 3523     loc = self._get_level_indexer(key, level=0)
#    3524     return _maybe_to_slice(loc)
#    3526 keylen = len(key)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\multi.py:3885, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3882         return slice(i, j, step)
#    3884 else:
# -> 3885     idx = self._get_loc_single_level_index(level_index, key)
#    3887     if level > 0 or self._lexsort_depth == 0:
#    3888         # Desired level is not sorted
#    3889         if isinstance(idx, slice):
#    3890             # test_get_loc_partial_timestamp_multiindex
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\multi.py:3458, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    3456     return -1
#    3457 else:
# -> 3458     return level_index.get_loc(key)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
df.columns = df.columns.droplevel(1)

# %%
print(df.columns)
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Price')

# %%
df['MA20'] = df['Close'].rolling(20).mean()
df['MA50'] = df['Close'].rolling(50).mean()

# %%
df['Signal'] = (df['MA20'] > df['MA50']).astype(int)
df['Position'] = df['Signal'].diff()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(df.index, df['Close'], label='Close')
plt.plot(df.index, df['MA20'], label='MA20')
plt.plot(df.index, df['MA50'], label='MA50')

plt.scatter(df[df['Position'] == 1].index,
            df[df['Position'] == 1]['Close'],
            label='BUY', marker='^')

plt.scatter(df[df['Position'] == -1].index,
            df[df['Position'] == -1]['Close'],
            label='SELL', marker='v')
plt.scatter(df[df['Buy']].index, df[df['Buy']]['Close'], marker='^')
plt.scatter(df[df['Sell']].index, df[df['Sell']]['Close'], marker='v')

plt.legend()
plt.title("Buy/Sell Signals")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Buy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 16
#      12
#      13 plt.scatter(df[df['Position'] == -1].index,
#      14             df[df['Position'] == -1]['Close'],
#      15             label='SELL', marker='v')
# ---> 16 plt.scatter(df[df['Buy']].index, df[df['Buy']]['Close'], marker='^')
#      17 plt.scatter(df[df['Sell']].index, df[df['Sell']]['Close'], marker='v')
#      18
#      19 plt.legend()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Buy'

# %%
df['MA_fast'] = df['Close'].rolling(5).mean()
df['MA_slow'] = df['Close'].rolling(20).mean()
df['Trend'] = df['Close'] > df['MA_slow']

df['Buy'] = (df['MA_fast'] > df['MA_slow']) & (df['Trend'])
df['Sell'] = (df['MA_fast'] < df['MA_slow']) & (~df['Trend'])



import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# Price line
plt.plot(df['Close'], label='Price')

# Moving Average
plt.plot(df['MA'], label='MA', linestyle='--')

# Buy signals (UP arrow)
plt.scatter(df[df['Buy']].index, df[df['Buy']]['Close'], 
            marker='^', color='green', label='Buy')

# Sell signals (DOWN arrow)

plt.scatter(df[df['Sell']].index, df[df['Sell']]['Close'], 
            marker='v', color='red', label='Sell')
df['Position'] = 0
df.loc[df['Buy'], 'Position'] = 1
df.loc[df['Sell'], 'Position'] = -1

df['Returns'] = df['Close'].pct_change()
df['Strategy'] = df['Position'].shift(1) * df['Returns']

plt.legend()
plt.title('Buy/Sell Signals')
plt.show()
